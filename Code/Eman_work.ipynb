# %%
# import 
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
from scipy import stats
import numpy as np
import scipy
import seaborn as sns

# pathfile
combined_pathfile = "../Data/combined_df.csv"

#read CSV
combined_df = pd.read_csv(combined_pathfile)
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965 entries, 0 to 964
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year_x             965 non-null    int64
#  1   week_x             965 non-null    int64
#  2   home_team_x        965 non-null    object
#  3   away_team_x        965 non-null    object
#  4   winner             965 non-null    object
#  5   tie                3 non-null      object
#  6   day                965 non-null    object
#  7   date               965 non-null    object
#  8   time               965 non-null    object
#  9   pts_win            965 non-null    int64
#  10  pts_loss           965 non-null    int64
#  11  yds_win            965 non-null    int64
#  12  turnovers_win      965 non-null    int64
#  13  yds_loss           965 non-null    int64
#  14  turnovers_loss     965 non-null    int64
#  15  home_team_name     965 non-null    object
#  16  home_team_city_x   965 non-null    object
#  17  away_team_name     965 non-null    object
#  18  away_team_city     965 non-null    object
#  19  Concat_Column      965 non-null    object
#  20  home_team_city_y   965 non-null    object
#  21  team_name          965 non-null    object
#  22  year_y             965 non-null    int64
#  23  total              965 non-null    int64
#  24  home               965 non-null    int64
#  25  away               965 non-null    int64
#  26  week_y             965 non-null    int64
#  27  weekly_attendance  965 non-null    float64
#  28  season             965 non-null    int64
#  29  week_num           965 non-null    int64
#  30  day_of_week        965 non-null    object
#  31  gametime_local     965 non-null    object
#  32  home_team_y        965 non-null    object
#  33  away_team_y        965 non-null    object
#  34  home_score         965 non-null    int64
#  35  away_score         965 non-null    int64
#  36  OT_flag            56 non-null     object
#  37  arrests            965 non-null    float64
#  38  division_game      965 non-null    object
#  39  DateTime           965 non-null    object
#  40  hour               965 non-null    int64
# dtypes: float64(2), int64(18), object(21)
# memory usage: 309.2+ KB

# %%
# look at data
combined_df.head(10)
# Out:
#    year_x  week_x           home_team_x          away_team_x  \
# 0    2011       1     Green Bay Packers   New Orleans Saints
# 1    2011       1      Baltimore Ravens  Pittsburgh Steelers
# 2    2011       1        Houston Texans   Indianapolis Colts
# 3    2011       1  Jacksonville Jaguars     Tennessee Titans
# 4    2011       1         Chicago Bears      Atlanta Falcons
# 5    2011       1    Kansas City Chiefs        Buffalo Bills
# 6    2011       1  Tampa Bay Buccaneers        Detroit Lions
# 7    2011       1     Arizona Cardinals    Carolina Panthers
# 8    2011       1    San Diego Chargers    Minnesota Vikings
# 9    2011       1   San Francisco 49ers     Seattle Seahawks
#
#                  winner  tie  day          date    time  pts_win  ...  \
# 0     Green Bay Packers  NaN  Thu   September 8  8:40PM       42  ...
# 1      Baltimore Ravens  NaN  Sun  September 11  1:05PM       35  ...
# 2        Houston Texans  NaN  Sun  September 11  1:05PM       34  ...
# 3  Jacksonville Jaguars  NaN  Sun  September 11  1:05PM       16  ...
# 4         Chicago Bears  NaN  Sun  September 11  1:06PM       30  ...
# 5         Buffalo Bills  NaN  Sun  September 11  1:06PM       41  ...
# 6         Detroit Lions  NaN  Sun  September 11  1:06PM       27  ...
# 7     Arizona Cardinals  NaN  Sun  September 11  4:15PM       28  ...
# 8    San Diego Chargers  NaN  Sun  September 11  4:20PM       24  ...
# 9   San Francisco 49ers  NaN  Sun  September 11  4:22PM       33  ...
#
#    gametime_local    home_team_y   away_team_y  home_score  away_score  \
# 0      7:30:00 PM      Green Bay   New Orleans          42          34
# 1      1:05:00 PM      Baltimore    Pittsburgh          35           7
# 2     12:00:00 PM        Houston  Indianapolis          34           7
# 3      1:00:00 PM   Jacksonville     Tennessee          16          14
# 4     12:00:00 PM        Chicago       Atlanta          30          12
# 5     12:00:00 PM    Kansas City       Buffalo           7          41
# 6      1:00:00 PM      Tampa Bay       Detroit          20          27
# 7      1:15:00 PM        Arizona      Carolina          28          21
# 8      1:15:00 PM      San Diego     Minnesota          24          17
# 9      1:15:00 PM  San Francisco       Seattle          33          17
#
#   OT_flag arrests division_game             DateTime hour
# 0     NaN     8.0             n  2011-09-08 19:30:00   19
# 1     NaN     1.0             y  2011-09-11 13:05:00   13
# 2     NaN     2.0             y  2011-09-11 12:00:00   12
# 3     NaN     4.0             y  2011-09-11 13:00:00   13
# 4     NaN     1.0             n  2011-09-11 12:00:00   12
# 5     NaN     0.0             n  2011-09-11 12:00:00   12
# 6     NaN     0.0             n  2011-09-11 13:00:00   13
# 7     NaN     5.0             n  2011-09-11 13:15:00   13
# 8     NaN    15.0             n  2011-09-11 13:15:00   13
# 9     NaN     3.0             y  2011-09-11 13:15:00   13
#
# [10 rows x 41 columns]

# %%
# Create filtered dataframe with only pertinent information
filtered_df = combined_df[['year_x','date','home_team_x','away_team_x','home_score','away_score','winner','weekly_attendance',
                           'arrests','team_name']]
# test for effect
filtered_df.head()
# Out:
#    year_x          date           home_team_x          away_team_x  \
# 0    2011   September 8     Green Bay Packers   New Orleans Saints
# 1    2011  September 11      Baltimore Ravens  Pittsburgh Steelers
# 2    2011  September 11        Houston Texans   Indianapolis Colts
# 3    2011  September 11  Jacksonville Jaguars     Tennessee Titans
# 4    2011  September 11         Chicago Bears      Atlanta Falcons
#
#    home_score  away_score                winner  weekly_attendance  arrests  \
# 0          42          34     Green Bay Packers            70555.0      8.0
# 1          35           7      Baltimore Ravens            71434.0      1.0
# 2          34           7        Houston Texans            71444.0      2.0
# 3          16          14  Jacksonville Jaguars            61619.0      4.0
# 4          30          12         Chicago Bears            62115.0      1.0
#
#   team_name
# 0   Packers
# 1    Ravens
# 2    Texans
# 3   Jaguars
# 4     Bears

# %%
# replace arrest NaN values with 0s
filtered_df['arrests'] = filtered_df['arrests'].fillna(0)

# test for effect
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965 entries, 0 to 964
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year_x             965 non-null    int64
#  1   date               965 non-null    object
#  2   home_team_x        965 non-null    object
#  3   away_team_x        965 non-null    object
#  4   home_score         965 non-null    int64
#  5   away_score         965 non-null    int64
#  6   winner             965 non-null    object
#  7   weekly_attendance  965 non-null    float64
#  8   arrests            965 non-null    float64
#  9   team_name          965 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 75.5+ KB
# /var/folders/mw/mrlbgjf56kx1vl5gclxkgggm0000gn/T/ipykernel_4807/1640956753.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['arrests'] = filtered_df['arrests'].fillna(0)

# %%
# create and fill new column showing percentage arrested
filtered_df['%_arrested'] = filtered_df['arrests']/filtered_df['weekly_attendance']*100
# Out:
# /var/folders/mw/mrlbgjf56kx1vl5gclxkgggm0000gn/T/ipykernel_4807/3688341273.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['%_arrested'] = filtered_df['arrests']/filtered_df['weekly_attendance']*100

# %%
# make new column showing homefield advantage based on conditions
# credit for base code https://www.statology.org/compare-two-columns-in-pandas/
#define conditions
conditions = [filtered_df['home_team_x'] == filtered_df['winner'], 
              filtered_df['away_team_x'] == filtered_df['winner']]

#define choices
choices = ['Yes', 'No']

#create new column in DataFrame that displays results of comparisons
filtered_df['home_advantage'] = np.select(conditions, choices, default='Tie')
# Out:
# /var/folders/mw/mrlbgjf56kx1vl5gclxkgggm0000gn/T/ipykernel_4807/287182915.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['home_advantage'] = np.select(conditions, choices, default='Tie')

# %%
# create and fill new column for score gap
# credit for base code https://numpy.org/doc/stable/reference/generated/numpy.where.html
HA = filtered_df['home_score'] - filtered_df['away_score']
AH = filtered_df['away_score'] - filtered_df['home_score']                                            
filtered_df['score_gap'] = np.where(HA < 0, AH, HA)

# reorganize columns
filtered_df = filtered_df.reindex(columns=['year_x', 'date', 'home_team_x', 'away_team_x','home_score','away_score',
                                           'score_gap','winner','home_advantage','weekly_attendance','arrests','%_arrested','team_name'])
# Out:
# /var/folders/mw/mrlbgjf56kx1vl5gclxkgggm0000gn/T/ipykernel_4807/883037999.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['score_gap'] = np.where(HA < 0, AH, HA)

# %%
# test results so far
filtered_df.head(20)
# Out:
#     year_x          date           home_team_x           away_team_x  \
# 0     2011   September 8     Green Bay Packers    New Orleans Saints
# 1     2011  September 11      Baltimore Ravens   Pittsburgh Steelers
# 2     2011  September 11        Houston Texans    Indianapolis Colts
# 3     2011  September 11  Jacksonville Jaguars      Tennessee Titans
# 4     2011  September 11         Chicago Bears       Atlanta Falcons
# 5     2011  September 11    Kansas City Chiefs         Buffalo Bills
# 6     2011  September 11  Tampa Bay Buccaneers         Detroit Lions
# 7     2011  September 11     Arizona Cardinals     Carolina Panthers
# 8     2011  September 11    San Diego Chargers     Minnesota Vikings
# 9     2011  September 11   San Francisco 49ers      Seattle Seahawks
# 10    2011  September 11   Washington Redskins       New York Giants
# 11    2011  September 11         New York Jets        Dallas Cowboys
# 12    2011  September 12        Denver Broncos       Oakland Raiders
# 13    2011  September 18      Tennessee Titans      Baltimore Ravens
# 14    2011  September 18         New York Jets  Jacksonville Jaguars
# 15    2011  September 18   Pittsburgh Steelers      Seattle Seahawks
# 16    2011  September 18     Carolina Panthers     Green Bay Packers
# 17    2011  September 18    Indianapolis Colts      Cleveland Browns
# 18    2011  September 18   Washington Redskins     Arizona Cardinals
# 19    2011  September 18   San Francisco 49ers        Dallas Cowboys
#
#     home_score  away_score  score_gap                winner home_advantage  \
# 0           42          34          8     Green Bay Packers            Yes
# 1           35           7         28      Baltimore Ravens            Yes
# 2           34           7         27        Houston Texans            Yes
# 3           16          14          2  Jacksonville Jaguars            Yes
# 4           30          12         18         Chicago Bears            Yes
# 5            7          41         34         Buffalo Bills             No
# 6           20          27          7         Detroit Lions             No
# 7           28          21          7     Arizona Cardinals            Yes
# 8           24          17          7    San Diego Chargers            Yes
# 9           33          17         16   San Francisco 49ers            Yes
# 10          28          14         14   Washington Redskins            Yes
# 11          27          24          3         New York Jets            Yes
# 12          20          23          3       Oakland Raiders             No
# 13          26          13         13      Tennessee Titans            Yes
# 14          32           3         29         New York Jets            Yes
# 15          24           0         24   Pittsburgh Steelers            Yes
# 16          23          30          7     Green Bay Packers             No
# 17          19          27          8      Cleveland Browns             No
# 18          22          21          1   Washington Redskins            Yes
# 19          24          27          3        Dallas Cowboys             No
#
#     weekly_attendance  arrests  %_arrested   team_name
# 0             70555.0      8.0    0.011339     Packers
# 1             71434.0      1.0    0.001400      Ravens
# 2             71444.0      2.0    0.002799      Texans
# 3             61619.0      4.0    0.006492     Jaguars
# 4             62115.0      1.0    0.001610       Bears
# 5             68755.0      0.0    0.000000      Chiefs
# 6             51274.0      0.0    0.000000  Buccaneers
# 7             60627.0      5.0    0.008247   Cardinals
# 8             66716.0     15.0    0.022483    Chargers
# 9             69732.0      3.0    0.004302       49ers
# 10            80121.0      1.0    0.001248    Redskins
# 11            78702.0     34.0    0.043201        Jets
# 12            75671.0      2.0    0.002643     Broncos
# 13            69143.0      0.0    0.000000      Titans
# 14            78834.0     23.0    0.029175        Jets
# 15            63663.0     15.0    0.023562    Steelers
# 16            73167.0      0.0    0.000000    Panthers
# 17            65035.0      2.0    0.003075       Colts
# 18            76330.0      2.0    0.002620    Redskins
# 19            69732.0      4.0    0.005736       49ers

# %%
filtered_df.head()
# Out:
#    year_x          date           home_team_x          away_team_x  \
# 0    2011   September 8     Green Bay Packers   New Orleans Saints
# 1    2011  September 11      Baltimore Ravens  Pittsburgh Steelers
# 2    2011  September 11        Houston Texans   Indianapolis Colts
# 3    2011  September 11  Jacksonville Jaguars     Tennessee Titans
# 4    2011  September 11         Chicago Bears      Atlanta Falcons
#
#    home_score  away_score  score_gap                winner home_advantage  \
# 0          42          34          8     Green Bay Packers            Yes
# 1          35           7         28      Baltimore Ravens            Yes
# 2          34           7         27        Houston Texans            Yes
# 3          16          14          2  Jacksonville Jaguars            Yes
# 4          30          12         18         Chicago Bears            Yes
#
#    weekly_attendance  arrests  %_arrested team_name
# 0            70555.0      8.0    0.011339   Packers
# 1            71434.0      1.0    0.001400    Ravens
# 2            71444.0      2.0    0.002799    Texans
# 3            61619.0      4.0    0.006492   Jaguars
# 4            62115.0      1.0    0.001610     Bears

# %%
# make and fill new columns for Home Wins/ Home Losses
filtered_df['home_wins'] = filtered_df.home_team_x == filtered_df.winner
filtered_df['home_loss'] = filtered_df.home_team_x != filtered_df.winner
win_perc = filtered_df.groupby('home_team_x').home_wins.sum()/ filtered_df.home_team_x.value_counts()*100
win_perc = win_perc.sort_values(ascending=False)
loss_perc = filtered_df.groupby('home_team_x').home_loss.sum()/ filtered_df.home_team_x.value_counts()*100
loss_perc = loss_perc.sort_values(ascending=True)
filtered_df.head(15)
# Out:
#     year_x          date           home_team_x           away_team_x  \
# 0     2011   September 8     Green Bay Packers    New Orleans Saints
# 1     2011  September 11      Baltimore Ravens   Pittsburgh Steelers
# 2     2011  September 11        Houston Texans    Indianapolis Colts
# 3     2011  September 11  Jacksonville Jaguars      Tennessee Titans
# 4     2011  September 11         Chicago Bears       Atlanta Falcons
# 5     2011  September 11    Kansas City Chiefs         Buffalo Bills
# 6     2011  September 11  Tampa Bay Buccaneers         Detroit Lions
# 7     2011  September 11     Arizona Cardinals     Carolina Panthers
# 8     2011  September 11    San Diego Chargers     Minnesota Vikings
# 9     2011  September 11   San Francisco 49ers      Seattle Seahawks
# 10    2011  September 11   Washington Redskins       New York Giants
# 11    2011  September 11         New York Jets        Dallas Cowboys
# 12    2011  September 12        Denver Broncos       Oakland Raiders
# 13    2011  September 18      Tennessee Titans      Baltimore Ravens
# 14    2011  September 18         New York Jets  Jacksonville Jaguars
#
#     home_score  away_score  score_gap                winner home_advantage  \
# 0           42          34          8     Green Bay Packers            Yes
# 1           35           7         28      Baltimore Ravens            Yes
# 2           34           7         27        Houston Texans            Yes
# 3           16          14          2  Jacksonville Jaguars            Yes
# 4           30          12         18         Chicago Bears            Yes
# 5            7          41         34         Buffalo Bills             No
# 6           20          27          7         Detroit Lions             No
# 7           28          21          7     Arizona Cardinals            Yes
# 8           24          17          7    San Diego Chargers            Yes
# 9           33          17         16   San Francisco 49ers            Yes
# 10          28          14         14   Washington Redskins            Yes
# 11          27          24          3         New York Jets            Yes
# 12          20          23          3       Oakland Raiders             No
# 13          26          13         13      Tennessee Titans            Yes
# 14          32           3         29         New York Jets            Yes
#
#     weekly_attendance  arrests  %_arrested   team_name  home_wins  home_loss
# 0             70555.0      8.0    0.011339     Packers       True      False
# 1             71434.0      1.0    0.001400      Ravens       True      False
# 2             71444.0      2.0    0.002799      Texans       True      False
# 3             61619.0      4.0    0.006492     Jaguars       True      False
# 4             62115.0      1.0    0.001610       Bears       True      False
# 5             68755.0      0.0    0.000000      Chiefs      False       True
# 6             51274.0      0.0    0.000000  Buccaneers      False       True
# 7             60627.0      5.0    0.008247   Cardinals       True      False
# 8             66716.0     15.0    0.022483    Chargers       True      False
# 9             69732.0      3.0    0.004302       49ers       True      False
# 10            80121.0      1.0    0.001248    Redskins       True      False
# 11            78702.0     34.0    0.043201        Jets       True      False
# 12            75671.0      2.0    0.002643     Broncos      False       True
# 13            69143.0      0.0    0.000000      Titans       True      False
# 14            78834.0     23.0    0.029175        Jets       True      False

# %%
# save win/loss percentages to varibales
w=win_perc
l=loss_perc

# %%
win_perc.head()
# Out:
# home_team_x
# New England Patriots    87.5
# Green Bay Packers       80.0
# Seattle Seahawks        77.5
# Denver Broncos          77.5
# Arizona Cardinals       72.5
# dtype: float64

# %%
w.corr
# Out:
# <bound method Series.corr of home_team_x
# New England Patriots    87.500000
# Green Bay Packers       80.000000
# Seattle Seahawks        77.500000
# Denver Broncos          77.500000
# Arizona Cardinals       72.500000
# Pittsburgh Steelers     72.500000
# Baltimore Ravens        70.967742
# Cincinnati Bengals      70.000000
# San Francisco 49ers     70.000000
# Carolina Panthers       62.500000
# Indianapolis Colts      62.500000
# New York Jets           56.410256
# Houston Texans          55.000000
# Chicago Bears           53.125000
# San Diego Chargers      52.500000
# Miami Dolphins          51.612903
# Kansas City Chiefs      51.282051
# New York Giants         50.000000
# Dallas Cowboys          47.500000
# Philadelphia Eagles     45.000000
# Washington Redskins     45.000000
# Oakland Raiders         37.837838
# Tennessee Titans        35.000000
# Jacksonville Jaguars    32.432432
# Tampa Bay Buccaneers    30.769231
# dtype: float64>

# %%
l.corr
# Out:
# <bound method Series.corr of home_team_x
# New England Patriots    12.500000
# Green Bay Packers       20.000000
# Seattle Seahawks        22.500000
# Denver Broncos          22.500000
# Arizona Cardinals       27.500000
# Pittsburgh Steelers     27.500000
# Baltimore Ravens        29.032258
# Cincinnati Bengals      30.000000
# San Francisco 49ers     30.000000
# Carolina Panthers       37.500000
# Indianapolis Colts      37.500000
# New York Jets           43.589744
# Houston Texans          45.000000
# Chicago Bears           46.875000
# San Diego Chargers      47.500000
# Miami Dolphins          48.387097
# Kansas City Chiefs      48.717949
# New York Giants         50.000000
# Dallas Cowboys          52.500000
# Philadelphia Eagles     55.000000
# Washington Redskins     55.000000
# Oakland Raiders         62.162162
# Tennessee Titans        65.000000
# Jacksonville Jaguars    67.567568
# Tampa Bay Buccaneers    69.230769
# dtype: float64>

# %%
win_df =  pd.DataFrame(win_perc).reset_index()
win_df.columns = ["home_team_x","percent"]
win_df["percent_type"] = "Win"
win_df.head()
# Out:
#             home_team_x  percent percent_type
# 0  New England Patriots     87.5          Win
# 1     Green Bay Packers     80.0          Win
# 2      Seattle Seahawks     77.5          Win
# 3        Denver Broncos     77.5          Win
# 4     Arizona Cardinals     72.5          Win

# %%
loss_df =  pd.DataFrame(loss_perc).reset_index()
loss_df.columns = ["home_team_x","percent"]
loss_df["percent_type"] = "Loss"
loss_df.head()
# Out:
#             home_team_x  percent percent_type
# 0  New England Patriots     12.5         Loss
# 1     Green Bay Packers     20.0         Loss
# 2      Seattle Seahawks     22.5         Loss
# 3        Denver Broncos     22.5         Loss
# 4     Arizona Cardinals     27.5         Loss

# %%
win_loss_df = pd.concat([win_df, loss_df], axis=0)
win_loss_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   home_team_x   50 non-null     object
#  1   percent       50 non-null     float64
#  2   percent_type  50 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
#  How strong is home field advantage (correlation between home team and home team wins)
# Credit to Prof Booth for the subplot bar chart code
lw_corr = l.corr(w)
print(f"The correlation of Home Wins to Home Losses is {lw_corr}. There is no correlaton to having homefield advantage and winning a game.")
win_perc=win_perc.sort_values(ascending=True)
loss_perc=loss_perc.sort_values(ascending=False)

N = 25
fig, ax = plt.subplots(figsize=(10,10))

ind = np.arange(N)  # the x locations for the groups
width=0.42
rects1 = ax.barh(ind, loss_perc.values, width, color='red', label="Loss")
rects2 = ax.barh(ind+width, win_perc.values, width, color='tab:green',label="Win")
ax.set_xlabel("Percent")
ax.set_ylabel("Teams")
ax.set_title("Home Win/Loss Comparison")
ax.set_yticks(ind + width / 2)
ax.set_yticklabels(win_perc.index )
ax.legend( (rects1[0], rects2[0]), ('Loss', 'Win'),frameon=False )
plt.show()
# Out:
# The correlation of Home Wins to Home Losses is -1.0. There is no correlaton to having homefield advantage and winning a game.

# %%
# Are there any correlation between score gap and total number of arrests on that game day
sns.set(rc= {'axes.facecolor':'green','figure.facecolor':'green'})
sns.regplot(x="score_gap", y="arrests", data=filtered_df, marker='x',scatter_kws= {"color": "black"},line_kws={'color': 'red'}).set(title='Arrests vs. Score Gap', xlabel='Score Gap', ylabel='Arrests')
;

#add correlation coefficient to plot
filtered_df['score_gap'].corr(filtered_df['arrests'])

print(f"The correlation of score gap in a game to the number of arrests that day is {filtered_df['score_gap'].corr(filtered_df['arrests'])}. There is very little correlaton to having a bigger gap in score and increased number of arrests. It can then be theorized that the closer a game is to a tie, the more likely it is that arrests will be made.")
# Out:
# The correlation of score gap in a game to the number of arrests that day is -0.052864223082118994. There is very little correlaton to having a bigger gap in score and increased number of arrests. It can then be theorized that the closer a game is to a tie, the more likely it is that arrests will be made.
